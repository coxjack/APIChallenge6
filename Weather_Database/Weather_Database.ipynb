# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san patricio
# Processing Record 2 of Set 1 | aklavik
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | port hedland
# Processing Record 7 of Set 1 | hovd
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | narsaq
# Processing Record 10 of Set 1 | touros
# Processing Record 11 of Set 1 | yumen
# Processing Record 12 of Set 1 | inhambane
# Processing Record 13 of Set 1 | eureka
# Processing Record 14 of Set 1 | bubaque
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | portland
# Processing Record 19 of Set 1 | bagotville
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | chokurdakh
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | curvelo
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | callaway
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | souillac
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 1 | codrington
# Processing Record 37 of Set 1 | talawdi
# City not found. Skipping...
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | puerto escondido
# Processing Record 40 of Set 1 | parkes
# Processing Record 41 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | warmbad
# Processing Record 46 of Set 1 | la libertad
# Processing Record 47 of Set 1 | alice springs
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | pevek
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | high rock
# Processing Record 5 of Set 2 | lakhtar
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | machinga
# Processing Record 10 of Set 2 | adre
# Processing Record 11 of Set 2 | tari
# Processing Record 12 of Set 2 | saint-pierre
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | chapais
# Processing Record 17 of Set 2 | salinopolis
# Processing Record 18 of Set 2 | primero de enero
# Processing Record 19 of Set 2 | vani
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | aksarka
# Processing Record 24 of Set 2 | coihaique
# Processing Record 25 of Set 2 | kavieng
# Processing Record 26 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 2 | autun
# Processing Record 28 of Set 2 | norman wells
# Processing Record 29 of Set 2 | mangan
# Processing Record 30 of Set 2 | sakakah
# Processing Record 31 of Set 2 | saint anthony
# Processing Record 32 of Set 2 | maua
# Processing Record 33 of Set 2 | port blair
# Processing Record 34 of Set 2 | udachnyy
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | okato
# Processing Record 37 of Set 2 | bundaberg
# Processing Record 38 of Set 2 | talcahuano
# Processing Record 39 of Set 2 | clyde river
# Processing Record 40 of Set 2 | silver city
# Processing Record 41 of Set 2 | balabac
# Processing Record 42 of Set 2 | ulaangom
# Processing Record 43 of Set 2 | katsuura
# Processing Record 44 of Set 2 | dodoma
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | caravelas
# Processing Record 47 of Set 2 | eucaliptus
# Processing Record 48 of Set 2 | natal
# Processing Record 49 of Set 2 | constitucion
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | martapura
# Processing Record 2 of Set 3 | kushva
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | naryan-mar
# Processing Record 5 of Set 3 | buraydah
# Processing Record 6 of Set 3 | tautira
# Processing Record 7 of Set 3 | faanui
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | comodoro rivadavia
# Processing Record 10 of Set 3 | kawalu
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | methoni
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | kupang
# Processing Record 17 of Set 3 | belgrade
# Processing Record 18 of Set 3 | abu samrah
# Processing Record 19 of Set 3 | nouadhibou
# Processing Record 20 of Set 3 | punta umbria
# Processing Record 21 of Set 3 | guebwiller
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | ampanihy
# Processing Record 25 of Set 3 | vaini
# Processing Record 26 of Set 3 | road town
# Processing Record 27 of Set 3 | taldan
# Processing Record 28 of Set 3 | austin
# Processing Record 29 of Set 3 | avera
# Processing Record 30 of Set 3 | ust-kuyga
# Processing Record 31 of Set 3 | abriaqui
# Processing Record 32 of Set 3 | port hardy
# Processing Record 33 of Set 3 | adrar
# Processing Record 34 of Set 3 | acajutla
# Processing Record 35 of Set 3 | pano polemidia
# Processing Record 36 of Set 3 | kharan
# Processing Record 37 of Set 3 | birjand
# Processing Record 38 of Set 3 | batticaloa
# Processing Record 39 of Set 3 | hamilton
# Processing Record 40 of Set 3 | aberdeen
# Processing Record 41 of Set 3 | los llanos de aridane
# Processing Record 42 of Set 3 | ozernovskiy
# Processing Record 43 of Set 3 | hilo
# Processing Record 44 of Set 3 | hanna
# Processing Record 45 of Set 3 | tateyama
# Processing Record 46 of Set 3 | prienai
# Processing Record 47 of Set 3 | biltine
# Processing Record 48 of Set 3 | almaty
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | port lincoln
# Processing Record 1 of Set 4 | yar-sale
# Processing Record 2 of Set 4 | ca mau
# Processing Record 3 of Set 4 | richards bay
# Processing Record 4 of Set 4 | vanavara
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | chumikan
# Processing Record 7 of Set 4 | poum
# Processing Record 8 of Set 4 | birao
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | lang son
# Processing Record 11 of Set 4 | east london
# Processing Record 12 of Set 4 | luderitz
# Processing Record 13 of Set 4 | hambantota
# Processing Record 14 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 4 | cururupu
# Processing Record 16 of Set 4 | margate
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | salinas
# Processing Record 19 of Set 4 | kaka
# Processing Record 20 of Set 4 | mercedes
# Processing Record 21 of Set 4 | alofi
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | adelaide
# Processing Record 24 of Set 4 | leningradskiy
# Processing Record 25 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 4 | talnakh
# Processing Record 27 of Set 4 | tias
# Processing Record 28 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 30 of Set 4 | filadelfia
# Processing Record 31 of Set 4 | kulhudhuffushi
# Processing Record 32 of Set 4 | porto santo
# Processing Record 33 of Set 4 | antalaha
# Processing Record 34 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 4 | kuji
# Processing Record 36 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 4 | mount isa
# Processing Record 38 of Set 4 | balkanabat
# Processing Record 39 of Set 4 | geraldton
# Processing Record 40 of Set 4 | vanimo
# Processing Record 41 of Set 4 | chichi
# Processing Record 42 of Set 4 | fortuna
# Processing Record 43 of Set 4 | algiers
# Processing Record 44 of Set 4 | piro
# Processing Record 45 of Set 4 | innisfail
# Processing Record 46 of Set 4 | lebu
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | chuy
# Processing Record 49 of Set 4 | iqaluit
# Processing Record 50 of Set 4 | valparaiso
# Processing Record 1 of Set 5 | oktyabrskiy
# Processing Record 2 of Set 5 | muros
# Processing Record 3 of Set 5 | carnarvon
# Processing Record 4 of Set 5 | guerrero negro
# Processing Record 5 of Set 5 | porto-vecchio
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | broome
# Processing Record 8 of Set 5 | ixtapa
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | seybaplaya
# Processing Record 11 of Set 5 | canico
# Processing Record 12 of Set 5 | knysna
# Processing Record 13 of Set 5 | lavrentiya
# Processing Record 14 of Set 5 | kidal
# Processing Record 15 of Set 5 | pacifica
# Processing Record 16 of Set 5 | taoudenni
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | juneau
# Processing Record 19 of Set 5 | pangnirtung
# Processing Record 20 of Set 5 | shaunavon
# Processing Record 21 of Set 5 | dudinka
# Processing Record 22 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 5 | gat
# Processing Record 24 of Set 5 | taiyuan
# Processing Record 25 of Set 5 | ribeira grande
# Processing Record 26 of Set 5 | pedasi
# Processing Record 27 of Set 5 | sorong
# Processing Record 28 of Set 5 | kavaratti
# Processing Record 29 of Set 5 | kamenka
# Processing Record 30 of Set 5 | san cristobal
# Processing Record 31 of Set 5 | samarai
# Processing Record 32 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 33 of Set 5 | charters towers
# Processing Record 34 of Set 5 | karla
# Processing Record 35 of Set 5 | mackenzie
# Processing Record 36 of Set 5 | suntar
# Processing Record 37 of Set 5 | pisco
# Processing Record 38 of Set 5 | volary
# Processing Record 39 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 5 | nizhnyaya tavda
# Processing Record 41 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 5 | ler
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | chalmette
# Processing Record 46 of Set 5 | mlonggo
# Processing Record 47 of Set 5 | cayenne
# Processing Record 48 of Set 5 | mehamn
# Processing Record 49 of Set 5 | vestmanna
# Processing Record 50 of Set 5 | tiksi
# Processing Record 1 of Set 6 | great yarmouth
# Processing Record 2 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 6 | kingaroy
# Processing Record 4 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 5 of Set 6 | thompson
# Processing Record 6 of Set 6 | verkhnyaya tura
# Processing Record 7 of Set 6 | falmouth
# Processing Record 8 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 6 | mahebourg
# Processing Record 10 of Set 6 | zhangjiakou
# Processing Record 11 of Set 6 | tianpeng
# Processing Record 12 of Set 6 | taybad
# Processing Record 13 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 14 of Set 6 | laguna
# Processing Record 15 of Set 6 | necochea
# Processing Record 16 of Set 6 | benghazi
# Processing Record 17 of Set 6 | beloha
# Processing Record 18 of Set 6 | yulara
# Processing Record 19 of Set 6 | corinth
# Processing Record 20 of Set 6 | hays
# Processing Record 21 of Set 6 | vilaka
# Processing Record 22 of Set 6 | songea
# Processing Record 23 of Set 6 | pilar
# Processing Record 24 of Set 6 | makakilo city
# Processing Record 25 of Set 6 | lagoa
# Processing Record 26 of Set 6 | evensk
# Processing Record 27 of Set 6 | gazli
# Processing Record 28 of Set 6 | nambucca heads
# Processing Record 29 of Set 6 | hasaki
# Processing Record 30 of Set 6 | tibati
# Processing Record 31 of Set 6 | vila
# Processing Record 32 of Set 6 | lujiang
# Processing Record 33 of Set 6 | dahra
# Processing Record 34 of Set 6 | luanda
# Processing Record 35 of Set 6 | fort nelson
# Processing Record 36 of Set 6 | balkhash
# Processing Record 37 of Set 6 | sorland
# Processing Record 38 of Set 6 | aquiraz
# Processing Record 39 of Set 6 | kapit
# Processing Record 40 of Set 6 | cuautepec
# Processing Record 41 of Set 6 | dikson
# Processing Record 42 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 6 | saint-ambroise
# Processing Record 45 of Set 6 | tiznit
# Processing Record 46 of Set 6 | cidreira
# Processing Record 47 of Set 6 | benjamin constant
# Processing Record 48 of Set 6 | ribas do rio pardo
# Processing Record 49 of Set 6 | kaniama
# Processing Record 50 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 7 | tahoua
# Processing Record 2 of Set 7 | bobonong
# City not found. Skipping...
# Processing Record 3 of Set 7 | saquena
# Processing Record 4 of Set 7 | padang
# Processing Record 5 of Set 7 | cuilco
# Processing Record 6 of Set 7 | baykit
# Processing Record 7 of Set 7 | dumas
# Processing Record 8 of Set 7 | bilma
# Processing Record 9 of Set 7 | kelme
# Processing Record 10 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 7 | leshukonskoye
# Processing Record 12 of Set 7 | dickson
# Processing Record 13 of Set 7 | samastipur
# Processing Record 14 of Set 7 | tawau
# Processing Record 15 of Set 7 | maracacume
# Processing Record 16 of Set 7 | vilyuysk
# Processing Record 17 of Set 7 | keflavik
# Processing Record 18 of Set 7 | meulaboh
# Processing Record 19 of Set 7 | verkhnyaya inta
# Processing Record 20 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 7 | longyearbyen
# Processing Record 22 of Set 7 | puerto carreno
# Processing Record 23 of Set 7 | voh
# Processing Record 24 of Set 7 | pascagoula
# Processing Record 25 of Set 7 | charlestown
# Processing Record 26 of Set 7 | madimba
# Processing Record 27 of Set 7 | manado
# Processing Record 28 of Set 7 | giyani
# Processing Record 29 of Set 7 | katobu
# Processing Record 30 of Set 7 | port elizabeth
# Processing Record 31 of Set 7 | santiago de cao
# Processing Record 32 of Set 7 | san jeronimo
# Processing Record 33 of Set 7 | lorengau
# Processing Record 34 of Set 7 | naze
# Processing Record 35 of Set 7 | kutum
# Processing Record 36 of Set 7 | matara
# Processing Record 37 of Set 7 | kahului
# Processing Record 38 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 7 | sao filipe
# Processing Record 40 of Set 7 | fairbanks
# Processing Record 41 of Set 7 | hirara
# Processing Record 42 of Set 7 | cortez
# Processing Record 43 of Set 7 | sucua
# Processing Record 44 of Set 7 | chapayevka
# Processing Record 45 of Set 7 | gambela
# Processing Record 46 of Set 7 | havoysund
# Processing Record 47 of Set 7 | kitimat
# Processing Record 48 of Set 7 | sonoita
# Processing Record 49 of Set 7 | mnogovershinnyy
# Processing Record 50 of Set 7 | parry sound
# Processing Record 1 of Set 8 | kishapu
# Processing Record 2 of Set 8 | freeport
# Processing Record 3 of Set 8 | cockburn town
# Processing Record 4 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 8 | ueda
# Processing Record 6 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 8 | tabas
# Processing Record 8 of Set 8 | korla
# Processing Record 9 of Set 8 | tilichiki
# Processing Record 10 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 11 of Set 8 | ibra
# Processing Record 12 of Set 8 | bereda
# Processing Record 13 of Set 8 | barrow
# Processing Record 14 of Set 8 | bere
# Processing Record 15 of Set 8 | auki
# Processing Record 16 of Set 8 | koslan
# Processing Record 17 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 8 | san andres
# Processing Record 19 of Set 8 | galesong
# Processing Record 20 of Set 8 | la ronge
# Processing Record 21 of Set 8 | vardo
# Processing Record 22 of Set 8 | porto novo
# Processing Record 23 of Set 8 | nome
# Processing Record 24 of Set 8 | aksu
# Processing Record 25 of Set 8 | hakkari
# Processing Record 26 of Set 8 | san juan
# Processing Record 27 of Set 8 | boguchar
# Processing Record 28 of Set 8 | beyneu
# Processing Record 29 of Set 8 | barajevo
# Processing Record 30 of Set 8 | yarmouth
# Processing Record 31 of Set 8 | merauke
# Processing Record 32 of Set 8 | hami
# Processing Record 33 of Set 8 | mocuba
# Processing Record 34 of Set 8 | pescara
# Processing Record 35 of Set 8 | sunbury
# Processing Record 36 of Set 8 | stromness
# Processing Record 37 of Set 8 | clinton
# Processing Record 38 of Set 8 | kailua
# Processing Record 39 of Set 8 | play cu
# City not found. Skipping...
# Processing Record 40 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 8 | katangli
# Processing Record 42 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 8 | piney green
# Processing Record 44 of Set 8 | la rioja
# Processing Record 45 of Set 8 | sistranda
# Processing Record 46 of Set 8 | dharmadam
# Processing Record 47 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 8 | kulgam
# Processing Record 49 of Set 8 | hobyo
# Processing Record 50 of Set 8 | pokhara
# Processing Record 1 of Set 9 | alta floresta
# Processing Record 2 of Set 9 | milyutinskaya
# Processing Record 3 of Set 9 | shimoda
# Processing Record 4 of Set 9 | trairi
# Processing Record 5 of Set 9 | bajil
# Processing Record 6 of Set 9 | chipata
# Processing Record 7 of Set 9 | metehara
# City not found. Skipping...
# Processing Record 8 of Set 9 | kinsale
# Processing Record 9 of Set 9 | sheregesh
# Processing Record 10 of Set 9 | sumbe
# Processing Record 11 of Set 9 | nuuk
# Processing Record 12 of Set 9 | saint-augustin
# Processing Record 13 of Set 9 | rawson
# Processing Record 14 of Set 9 | redange
# Processing Record 15 of Set 9 | komsomolskiy
# Processing Record 16 of Set 9 | pandan niog
# Processing Record 17 of Set 9 | santiago
# Processing Record 18 of Set 9 | jijiga
# Processing Record 19 of Set 9 | leh
# Processing Record 20 of Set 9 | dongsheng
# Processing Record 21 of Set 9 | strenci
# Processing Record 22 of Set 9 | virginia beach
# Processing Record 23 of Set 9 | vostok
# Processing Record 24 of Set 9 | lhokseumawe
# Processing Record 25 of Set 9 | ilulissat
# Processing Record 26 of Set 9 | caraquet
# Processing Record 27 of Set 9 | svetlyy
# Processing Record 28 of Set 9 | pandan
# Processing Record 29 of Set 9 | brae
# Processing Record 30 of Set 9 | labuhan
# Processing Record 31 of Set 9 | brunswick
# Processing Record 32 of Set 9 | thano bula khan
# City not found. Skipping...
# Processing Record 33 of Set 9 | aban
# Processing Record 34 of Set 9 | nemuro
# Processing Record 35 of Set 9 | smithers
# Processing Record 36 of Set 9 | lithakia
# Processing Record 37 of Set 9 | rudnogorsk
# Processing Record 38 of Set 9 | ulagan
# Processing Record 39 of Set 9 | botngard
# Processing Record 40 of Set 9 | yenagoa
# Processing Record 41 of Set 9 | astanajapura
# Processing Record 42 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 9 | rabo de peixe
# Processing Record 45 of Set 9 | rio grande
# Processing Record 46 of Set 9 | usinsk
# Processing Record 47 of Set 9 | kenai
# Processing Record 48 of Set 9 | turochak
# Processing Record 49 of Set 9 | acapulco
# Processing Record 50 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 10 | matagami
# Processing Record 2 of Set 10 | mukhen
# Processing Record 3 of Set 10 | villa carlos paz
# Processing Record 4 of Set 10 | sabang
# Processing Record 5 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 10 | kantunilkin
# Processing Record 8 of Set 10 | mouila
# Processing Record 9 of Set 10 | biak
# Processing Record 10 of Set 10 | tongren
# Processing Record 11 of Set 10 | sur
# Processing Record 12 of Set 10 | mogadouro
# Processing Record 13 of Set 10 | general higinio morinigo
# Processing Record 14 of Set 10 | severnoye
# Processing Record 15 of Set 10 | jaramana
# City not found. Skipping...
# Processing Record 16 of Set 10 | itarema
# Processing Record 17 of Set 10 | waitakere
# Processing Record 18 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 10 | tungor
# Processing Record 20 of Set 10 | humaita
# Processing Record 21 of Set 10 | cabo san lucas
# Processing Record 22 of Set 10 | ponta delgada
# Processing Record 23 of Set 10 | kachiry
# Processing Record 24 of Set 10 | menongue
# Processing Record 25 of Set 10 | northam
# Processing Record 26 of Set 10 | merke
# Processing Record 27 of Set 10 | yerbogachen
# Processing Record 28 of Set 10 | erenhot
# Processing Record 29 of Set 10 | puerto del rosario
# Processing Record 30 of Set 10 | vila velha
# Processing Record 31 of Set 10 | kampot
# Processing Record 32 of Set 10 | groton
# Processing Record 33 of Set 10 | joensuu
# Processing Record 34 of Set 10 | dzhebariki-khaya
# Processing Record 35 of Set 10 | khasan
# Processing Record 36 of Set 10 | sinnamary
# Processing Record 37 of Set 10 | vestmannaeyjar
# Processing Record 38 of Set 10 | turukhansk
# Processing Record 39 of Set 10 | lapeer
# Processing Record 40 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 10 | khategaon
# Processing Record 42 of Set 10 | taree
# Processing Record 43 of Set 10 | san julian
# Processing Record 44 of Set 10 | maceio
# Processing Record 45 of Set 10 | wodonga
# Processing Record 46 of Set 10 | bilibino
# Processing Record 47 of Set 10 | russell
# Processing Record 48 of Set 10 | mastic beach
# Processing Record 49 of Set 10 | areosa
# Processing Record 50 of Set 10 | imeni poliny osipenko
# Processing Record 1 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 11 | morondava
# Processing Record 3 of Set 11 | vila franca do campo
# Processing Record 4 of Set 11 | brownsville
# Processing Record 5 of Set 11 | tezu
# Processing Record 6 of Set 11 | kapuskasing
# Processing Record 7 of Set 11 | sabla
# Processing Record 8 of Set 11 | amahai
# Processing Record 9 of Set 11 | esil
# Processing Record 10 of Set 11 | mount gambier
# Processing Record 11 of Set 11 | garango
# Processing Record 12 of Set 11 | geoagiu
# Processing Record 13 of Set 11 | spiridonovka
# Processing Record 14 of Set 11 | coldstream
# Processing Record 15 of Set 11 | znamenskoye
# Processing Record 16 of Set 11 | taltal
# Processing Record 17 of Set 11 | ceres
# Processing Record 18 of Set 11 | ostrovnoy
# Processing Record 19 of Set 11 | gao
# Processing Record 20 of Set 11 | dakar
# Processing Record 21 of Set 11 | butembo
# Processing Record 22 of Set 11 | tual
# Processing Record 23 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 24 of Set 11 | wamba
# Processing Record 25 of Set 11 | orsta
# Processing Record 26 of Set 11 | nevelsk
# Processing Record 27 of Set 11 | tsumeb
# Processing Record 28 of Set 11 | panguna
# Processing Record 29 of Set 11 | riverton
# Processing Record 30 of Set 11 | moron
# Processing Record 31 of Set 11 | college
# Processing Record 32 of Set 11 | kirkuk
# Processing Record 33 of Set 11 | funtua
# Processing Record 34 of Set 11 | jermuk
# Processing Record 35 of Set 11 | mopti
# Processing Record 36 of Set 11 | pavlivka
# Processing Record 37 of Set 11 | liepaja
# Processing Record 38 of Set 11 | reefton
# City not found. Skipping...
# Processing Record 39 of Set 11 | batagay
# Processing Record 40 of Set 11 | yarada
# Processing Record 41 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 11 | constantine
# Processing Record 43 of Set 11 | kuybyshevo
# Processing Record 44 of Set 11 | champerico
# Processing Record 45 of Set 11 | sapozhok
# Processing Record 46 of Set 11 | tocopilla
# Processing Record 47 of Set 11 | autazes
# Processing Record 48 of Set 11 | namatanai
# Processing Record 49 of Set 11 | zuwarah
# Processing Record 50 of Set 11 | tigil
# Processing Record 1 of Set 12 | sokoni
# Processing Record 2 of Set 12 | ajdabiya
# Processing Record 3 of Set 12 | independenta
# Processing Record 4 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 12 | westport
# Processing Record 6 of Set 12 | korgen
# Processing Record 7 of Set 12 | ternate
# Processing Record 8 of Set 12 | obo
# Processing Record 9 of Set 12 | reporoa
# Processing Record 10 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 12 | bafq
# Processing Record 12 of Set 12 | dalvik
# Processing Record 13 of Set 12 | bukan
# Processing Record 14 of Set 12 | wilkie
# Processing Record 15 of Set 12 | terrace
# Processing Record 16 of Set 12 | atar
# Processing Record 17 of Set 12 | saldanha
# Processing Record 18 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 19 of Set 12 | faya
# Processing Record 20 of Set 12 | dourbali
# Processing Record 21 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 12 | grand gaube
# Processing Record 23 of Set 12 | bud
# Processing Record 24 of Set 12 | saurimo
# Processing Record 25 of Set 12 | dukat
# Processing Record 26 of Set 12 | palmer
# Processing Record 27 of Set 12 | vangaindrano
# Processing Record 28 of Set 12 | palembang
# Processing Record 29 of Set 12 | sovetsk
# Processing Record 30 of Set 12 | cotonou
# Processing Record 31 of Set 12 | dingle
# Processing Record 32 of Set 12 | wewak
# Processing Record 33 of Set 12 | bathsheba
# Processing Record 34 of Set 12 | saint-joseph
# Processing Record 35 of Set 12 | borogontsy
# Processing Record 36 of Set 12 | moranbah
# Processing Record 37 of Set 12 | camacha
# Processing Record 38 of Set 12 | verkh-usugli
# Processing Record 39 of Set 12 | christchurch
# Processing Record 40 of Set 12 | olinda
# Processing Record 41 of Set 12 | shenkursk
# Processing Record 42 of Set 12 | namibe
# Processing Record 43 of Set 12 | capaci
# Processing Record 44 of Set 12 | zhigansk
# Processing Record 45 of Set 12 | tutoia
# Processing Record 46 of Set 12 | southbridge
# Processing Record 47 of Set 12 | osa
# Processing Record 48 of Set 12 | kuytun
# Processing Record 49 of Set 12 | shawnee
# Processing Record 50 of Set 12 | ulefoss
# Processing Record 1 of Set 13 | ust-ilimsk
# Processing Record 2 of Set 13 | manaus
# Processing Record 3 of Set 13 | puquio
# Processing Record 4 of Set 13 | pizhanka
# Processing Record 5 of Set 13 | maldonado
# Processing Record 6 of Set 13 | oistins
# Processing Record 7 of Set 13 | mareeba
# Processing Record 8 of Set 13 | booue
# Processing Record 9 of Set 13 | chapleau
# Processing Record 10 of Set 13 | nadym
# Processing Record 11 of Set 13 | pereslavl-zalesskiy
# Processing Record 12 of Set 13 | half moon bay
# Processing Record 13 of Set 13 | kumluca
# Processing Record 14 of Set 13 | bama
# Processing Record 15 of Set 13 | talaya
# Processing Record 16 of Set 13 | husavik
# Processing Record 17 of Set 13 | narrabri
# Processing Record 18 of Set 13 | marystown
# Processing Record 19 of Set 13 | sibolga
# Processing Record 20 of Set 13 | sidi ali
# Processing Record 21 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 13 | hualmay
# Processing Record 23 of Set 13 | gedo
# Processing Record 24 of Set 13 | abu dhabi
# Processing Record 25 of Set 13 | ayan
# Processing Record 26 of Set 13 | vega de alatorre
# Processing Record 27 of Set 13 | watertown
# Processing Record 28 of Set 13 | sept-iles
# Processing Record 29 of Set 13 | bambanglipuro
# Processing Record 30 of Set 13 | aykhal
# Processing Record 31 of Set 13 | goundam
# Processing Record 32 of Set 13 | charleston
# Processing Record 33 of Set 13 | capao da canoa
# Processing Record 34 of Set 13 | turayf
# Processing Record 35 of Set 13 | catanduva
# Processing Record 36 of Set 13 | praia da vitoria
# Processing Record 37 of Set 13 | baoqing
# Processing Record 38 of Set 13 | great bend
# Processing Record 39 of Set 13 | mandera
# Processing Record 40 of Set 13 | khilok
# Processing Record 41 of Set 13 | koutsouras
# Processing Record 42 of Set 13 | kemijarvi
# Processing Record 43 of Set 13 | salalah
# Processing Record 44 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 13 | puerto suarez
# Processing Record 46 of Set 13 | port hueneme
# Processing Record 47 of Set 13 | port macquarie
# Processing Record 48 of Set 13 | sulangan
# Processing Record 49 of Set 13 | andros
# Processing Record 50 of Set 13 | tiruchchirappalli
# Processing Record 1 of Set 14 | nyurba
# Processing Record 2 of Set 14 | zhezkazgan
# Processing Record 3 of Set 14 | embonas
# Processing Record 4 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 14 | vao
# Processing Record 6 of Set 14 | tubuala
# Processing Record 7 of Set 14 | inta
# Processing Record 8 of Set 14 | glotovka
# Processing Record 9 of Set 14 | bria
# Processing Record 10 of Set 14 | sao joao da barra
# Processing Record 11 of Set 14 | zheleznodorozhnyy
# Processing Record 12 of Set 14 | anadyr
# Processing Record 13 of Set 14 | severomuysk
# Processing Record 14 of Set 14 | miyako
# Processing Record 15 of Set 14 | hailun
# Processing Record 16 of Set 14 | mayo
# Processing Record 17 of Set 14 | olafsvik
# Processing Record 18 of Set 14 | trinidad
# Processing Record 19 of Set 14 | berlevag
# Processing Record 20 of Set 14 | ruston
# Processing Record 21 of Set 14 | amarkantak
# Processing Record 22 of Set 14 | fairhope
# Processing Record 23 of Set 14 | conakry
# Processing Record 24 of Set 14 | kloulklubed
# Processing Record 25 of Set 14 | tarakan
# Processing Record 26 of Set 14 | te anau
# Processing Record 27 of Set 14 | le vauclin
# Processing Record 28 of Set 14 | vryburg
# Processing Record 29 of Set 14 | obigarm
# Processing Record 30 of Set 14 | corn island
# Processing Record 31 of Set 14 | bintulu
# Processing Record 32 of Set 14 | roald
# Processing Record 33 of Set 14 | bonthe
# Processing Record 34 of Set 14 | palasa
# Processing Record 35 of Set 14 | lixourion
# Processing Record 36 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 37 of Set 14 | nantucket
# Processing Record 38 of Set 14 | marsh harbour
# Processing Record 39 of Set 14 | gobabis
# Processing Record 40 of Set 14 | huarmey
# Processing Record 41 of Set 14 | wanaka
# Processing Record 42 of Set 14 | warangal
# Processing Record 43 of Set 14 | shahr-e kord
# Processing Record 44 of Set 14 | costinesti
# Processing Record 45 of Set 14 | nelson bay
# Processing Record 46 of Set 14 | allen
# Processing Record 47 of Set 14 | rocha
# Processing Record 48 of Set 14 | cocobeach
# Processing Record 49 of Set 14 | mandalgovi
# Processing Record 50 of Set 14 | sulphur springs
# Processing Record 1 of Set 15 | illescas
# Processing Record 2 of Set 15 | capreol
# Processing Record 3 of Set 15 | yaan
# Processing Record 4 of Set 15 | koumac
# Processing Record 5 of Set 15 | chabahar
# Processing Record 6 of Set 15 | bosaso
# Processing Record 7 of Set 15 | ancud
# Processing Record 8 of Set 15 | sanguem
# Processing Record 9 of Set 15 | tura
# Processing Record 10 of Set 15 | awbari
# Processing Record 11 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 12 of Set 15 | opotiki
# Processing Record 13 of Set 15 | paro
# Processing Record 14 of Set 15 | camabatela
# Processing Record 15 of Set 15 | port pirie
# Processing Record 16 of Set 15 | donja orahovica
# City not found. Skipping...
# Processing Record 17 of Set 15 | takaka
# Processing Record 18 of Set 15 | deputatskiy
# Processing Record 19 of Set 15 | samsun
# Processing Record 20 of Set 15 | boda
# Processing Record 21 of Set 15 | pedernales
# Processing Record 22 of Set 15 | manaure
# Processing Record 23 of Set 15 | griffith
# Processing Record 24 of Set 15 | semnan
# Processing Record 25 of Set 15 | karratha
# Processing Record 26 of Set 15 | amga
# Processing Record 27 of Set 15 | mangaratiba
# Processing Record 28 of Set 15 | jian
# Processing Record 29 of Set 15 | belyy yar
# Processing Record 30 of Set 15 | el balyana
# City not found. Skipping...
# Processing Record 31 of Set 15 | saint-georges
# Processing Record 32 of Set 15 | klaksvik
# Processing Record 33 of Set 15 | ambilobe
# Processing Record 34 of Set 15 | veinticinco de mayo
# Processing Record 35 of Set 15 | weatherford
# Processing Record 36 of Set 15 | grimari
# City not found. Skipping...
# Processing Record 37 of Set 15 | elko
# Processing Record 38 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 39 of Set 15 | davidson
# Processing Record 40 of Set 15 | khani
# Processing Record 41 of Set 15 | caraballeda
# Processing Record 42 of Set 15 | roebourne
# Processing Record 43 of Set 15 | niquelandia
# Processing Record 44 of Set 15 | rosarito
# Processing Record 45 of Set 15 | san policarpo
# Processing Record 46 of Set 15 | quatre cocos
# Processing Record 47 of Set 15 | yinchuan
# Processing Record 48 of Set 15 | nauta
# Processing Record 49 of Set 15 | port keats
# Processing Record 50 of Set 15 | catalina
# Processing Record 1 of Set 16 | matay
# Processing Record 2 of Set 16 | kashan
# Processing Record 3 of Set 16 | sakaiminato
# Processing Record 4 of Set 16 | kifri
# Processing Record 5 of Set 16 | ekpoma
# Processing Record 6 of Set 16 | komsomolskoye
# Processing Record 7 of Set 16 | jonkoping
# Processing Record 8 of Set 16 | wurzburg
# Processing Record 9 of Set 16 | flinders
# Processing Record 10 of Set 16 | kyra
# Processing Record 11 of Set 16 | denia
# Processing Record 12 of Set 16 | shaumiani
# Processing Record 13 of Set 16 | vokhma
# Processing Record 14 of Set 16 | yangambi
# Processing Record 15 of Set 16 | alness
# Processing Record 16 of Set 16 | karwar
# Processing Record 17 of Set 16 | shaping
# Processing Record 18 of Set 16 | praia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    San Patricio  28.0170  -97.5169     68.41        51           0
# 1         Aklavik  68.2191 -135.0107      1.40        78          75
# 2         Ushuaia -54.8000  -68.3000     47.86        66          75
# 3       Esperance -33.8667  121.9000     69.64        60          59
# 4    Port Hedland -20.3167  118.5667     82.45        83          40
# ..            ...      ...       ...       ...       ...         ...
# 700      Yangambi   0.8102   24.4336     78.33        34          70
# 701        Alness  57.6960   -4.2551     44.37        88         100
# 702        Karwar  14.8000   74.1333     74.43        63          16
# 703       Shaping  22.7545  112.9565     57.49        40          88
# 704         Praia  14.9215  -23.5087     70.34        68         100
#
#      Wind Speed Country Current Description
# 0          8.63      US           clear sky
# 1          5.75      CA          light snow
# 2         25.32      AR       broken clouds
# 3          8.57      AU          light rain
# 4         17.27      AU    scattered clouds
# ..          ...     ...                 ...
# 700        2.04      CD       broken clouds
# 701        7.07      GB     overcast clouds
# 702        8.77      IN          few clouds
# 703        9.46      CN     overcast clouds
# 704       26.46      CV     overcast clouds
#
# [705 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat","Lng","Max Temp",'Humidity',"Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    San Patricio      US  28.0170  -97.5169     68.41        51           0
# 1         Aklavik      CA  68.2191 -135.0107      1.40        78          75
# 2         Ushuaia      AR -54.8000  -68.3000     47.86        66          75
# 3       Esperance      AU -33.8667  121.9000     69.64        60          59
# 4    Port Hedland      AU -20.3167  118.5667     82.45        83          40
# ..            ...     ...      ...       ...       ...       ...         ...
# 700      Yangambi      CD   0.8102   24.4336     78.33        34          70
# 701        Alness      GB  57.6960   -4.2551     44.37        88         100
# 702        Karwar      IN  14.8000   74.1333     74.43        63          16
# 703       Shaping      CN  22.7545  112.9565     57.49        40          88
# 704         Praia      CV  14.9215  -23.5087     70.34        68         100
#
#      Wind Speed Current Description
# 0          8.63           clear sky
# 1          5.75          light snow
# 2         25.32       broken clouds
# 3          8.57          light rain
# 4         17.27    scattered clouds
# ..          ...                 ...
# 700        2.04       broken clouds
# 701        7.07     overcast clouds
# 702        8.77          few clouds
# 703        9.46     overcast clouds
# 704       26.46     overcast clouds
#
# [705 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
